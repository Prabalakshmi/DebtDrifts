# %%
# Fetching tweets and putting it into a dataframe and csv file

import snscrape.modules.twitter as sntwitter
import pandas as pd

#query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"

# input hashtag you want to search here
query = "(#studentdebtbomb) until:2022-12-07 since:2022-09-15"
tweets = []
# number of tweets we need
limit = 100000

i = 1

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if i % 1000 == 0:
        print("Fetched", i, "tweets so far")
        print('-'*100)
    
    if len(tweets) == limit:
        break
        
    i += 1    

    tweets.append([tweet.date, tweet.user.username, tweet.user.id, tweet.content, tweet.user.location, tweet.user.profileImageUrl])
        
print('Process halted after fetching', len(tweets), 'tweets')        
df_studentdebtbomb = pd.DataFrame(tweets, columns=['Date', 'User Name', 'User ID', 'Tweet', 'User Location', 'Image URL'])
#print(df)
# df_studentdebtbomb.to_csv('student_debt_bomb.csv')
# print("Process completed")
# Out:
# Process halted after fetching 108 tweets

# %%
df_studentdebtbomb.to_csv('student_debt_bomb.csv')
print("Process completed")
# Out:
# Process completed

# %%
# Fetching tweets and putting it into a dataframe and csv file

import snscrape.modules.twitter as sntwitter
import pandas as pd

#query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"

# input hashtag you want to search here
query = "(#loanforgiveness) until:2022-12-07 since:2022-09-15"
tweets = []
# number of tweets we need
limit = 100000

i = 1

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if i % 500 == 0:
        print("Fetched", i, "tweets so far")
        print('-'*100)
    
    if len(tweets) == limit:
        break
        
    i += 1    

    tweets.append([tweet.date, tweet.user.username, tweet.user.id, tweet.content, tweet.user.location, tweet.user.profileImageUrl])
        
print('Process halted after fetching', len(tweets), 'tweets')        
df_loanforgiveness = pd.DataFrame(tweets, columns=['Date', 'User Name', 'User ID', 'Tweet', 'User Location', 'Image URL'])
#print(df)
# df_loanforgiveness.to_csv('loan_forgiveness.csv')
# print("Process completed")
# Out:
# Fetched 500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Process halted after fetching 594 tweets

# %%
df_loanforgiveness.to_csv('loan_forgiveness.csv')
print("Process completed")
# Out:
# Process completed

# %%
# Fetching tweets and putting it into a dataframe and csv file

import snscrape.modules.twitter as sntwitter
import pandas as pd

#query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"

# input hashtag you want to search here
query = "(#studentloandebt) until:2022-12-07 since:2022-09-15"
tweets = []
# number of tweets we need
limit = 100000

i = 1

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if i % 500 == 0:
        print("Fetched", i, "tweets so far")
        print('-'*100)
    
    if len(tweets) == limit:
        break
        
    i += 1    

    tweets.append([tweet.date, tweet.user.username, tweet.user.id, tweet.content, tweet.user.location, tweet.user.profileImageUrl])
        
print('Process halted after fetching', len(tweets), 'tweets')        
df_studentloandebt = pd.DataFrame(tweets, columns=['Date', 'User Name', 'User ID', 'Tweet', 'User Location', 'Image URL'])
#print(df)
# df_studentloandebt.to_csv('student_loan_debt.csv')
# print("Process completed")
# Out:
# Fetched 500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 1000 tweets so far
# ----------------------------------------------------------------------------------------------------
# Process halted after fetching 1069 tweets

# %%
df_studentloandebt.to_csv('student_loan_debt.csv')
print("Process completed")
# Out:
# Process completed

# %%
# Fetching tweets and putting it into a dataframe and csv file

import snscrape.modules.twitter as sntwitter
import pandas as pd

#query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"

# input hashtag you want to search here
query = "(#studentdebt) until:2022-12-07 since:2022-09-15"
tweets = []
# number of tweets we need
limit = 100000

i = 1

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if i % 500 == 0:
        print("Fetched", i, "tweets so far")
        print('-'*100)
    
    if len(tweets) == limit:
        break
        
    i += 1    

    tweets.append([tweet.date, tweet.user.username, tweet.user.id, tweet.content, tweet.user.location, tweet.user.profileImageUrl])
        
print('Process halted after fetching', len(tweets), 'tweets')        
df_studentdebt = pd.DataFrame(tweets, columns=['Date', 'User Name', 'User ID', 'Tweet', 'User Location', 'Image URL'])
#print(df)
# df_studentdebt.to_csv('student_debt.csv')
# print("Process completed")
# Out:
# Fetched 500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 1000 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 1500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 2000 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 2500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Process halted after fetching 2578 tweets

# %%
df_studentdebt.to_csv('student_debt.csv')
print("Process completed")
# Out:
# Process completed

# %%
# Fetching tweets and putting it into a dataframe and csv file

import snscrape.modules.twitter as sntwitter
import pandas as pd

#query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"

# input hashtag you want to search here
query = "(#studentloan) until:2022-12-07 since:2022-09-15"
tweets = []
# number of tweets we need
limit = 100000

i = 1

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if i % 500 == 0:
        print("Fetched", i, "tweets so far")
        print('-'*100)
    
    if len(tweets) == limit:
        break
        
    i += 1    

    tweets.append([tweet.date, tweet.user.username, tweet.user.id, tweet.content, tweet.user.location, tweet.user.profileImageUrl])
        
print('Process halted after fetching', len(tweets), 'tweets')        
df_studentloan = pd.DataFrame(tweets, columns=['Date', 'User Name', 'User ID', 'Tweet', 'User Location', 'Image URL'])
#print(df)
# df_studentloan.to_csv('student_loan.csv')
# print("Process completed")
# Out:
# Fetched 500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 1000 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 1500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 2000 tweets so far
# ----------------------------------------------------------------------------------------------------
# Fetched 2500 tweets so far
# ----------------------------------------------------------------------------------------------------
# Process halted after fetching 2681 tweets

# %%
df_studentloan.to_csv('student_loan.csv')
print("Process completed")
# Out:
# Process completed

# %%
df_studentloanforgiveness = pd.read_csv('student_loan_forgiveness.csv')

# %%
# df_studentloanforgiveness['Location'] = 'United States'
# df_studentdebtbomb['Location'] = 'United States'
# df_loanforgiveness['Location'] = 'United States'
# df_studentloandebt['Location'] = 'United States'
# df_studentdebt['Location'] = 'United States'
# df_studentloan['Location'] = 'United States'
# Out:
#                         Date User Name    User ID  \
# 0  2022-12-07 19:25:12+00:00  NACBAorg  380532332
# 1  2022-12-07 19:07:23+00:00  NACBAorg  380532332
# 2  2022-12-07 19:03:42+00:00  NACBAorg  380532332
# 3  2022-12-07 18:59:51+00:00  NACBAorg  380532332
# 4  2022-12-06 21:15:15+00:00  NACBAorg  380532332
# ..                       ...       ...        ...
# 95 2022-09-30 18:15:14+00:00  NACBAorg  380532332
#
#                  User Location  \
# 0
# 1   In the lego you stepped on
# 2                 New York, NY
# 3                   Texas, USA
# 4
# ..                         ...
# 95
# 96
# 97
# 98
# 99
#
#                                             Image URL
# 0   https://abs.twimg.com/sticky/default_profile_i...
# 1   https://pbs.twimg.com/profile_images/870712806...
# 2   https://pbs.twimg.com/profile_images/548641232...
# 3   https://pbs.twimg.com/profile_images/758470995...
# 4   https://pbs.twimg.com/profile_images/137775044...
# ..                                                ...
# 95  https://pbs.twimg.com/profile_images/140849543...
# 96  https://pbs.twimg.com/profile_images/140849543...
# 97  https://pbs.twimg.com/profile_images/140849543...
# 98  https://pbs.twimg.com/profile_images/140849543...
# 99  https://pbs.twimg.com/profile_images/140849543...
#
# [200 rows x 6 columns]

# %%
df.drop(['User Location'], axis=1)
df
# Out:
#                         Date       User Name              User ID  \
# 0  2022-12-08 04:10:58+00:00         KLudsey  1600675031587192833
# 1  2022-12-08 04:04:47+00:00     ShittyJesus   870033934838452225
# 2  2022-12-08 03:17:42+00:00    scottandrewh             79532585
# 3  2022-12-08 02:32:47+00:00   pumpkinstench             50763295
# 4  2022-12-08 01:50:03+00:00  moneytalksdocu  1376587864549494796
# ..                       ...             ...                  ...
# 95 2022-09-30 18:15:14+00:00        NACBAorg            380532332
# 96 2022-09-30 16:20:15+00:00        NACBAorg            380532332
# 97 2022-09-30 15:38:08+00:00        NACBAorg            380532332
# 98 2022-09-29 14:59:14+00:00        NACBAorg            380532332
# 99 2022-09-28 18:10:20+00:00        NACBAorg            380532332
#
#                                                 Tweet  \
# 0   9 million people got incorrect email about 'ap...
# 1   The argument of "we took the PPP loans knowing...
# 2   Whoever coined the phrase "do what you love, a...
# 3   @SenSchumer Big things except #studentloanforg...
# 4   What's your student loan story? Share yours he...
# ..                                                ...
# 95  "In a reversal, the Education Dept. is excludi...
# 96  "CFPB Supervisory Examinations Find Violations...
# 97  "Biden administration scales back student debt...
# 98  Today's live NACBA webinar "Federal Student Lo...
# 99  🚨Don't miss tomorrow's #NACBA webinar "Federal...
#
#                  User Location  \
# 0
# 1   In the lego you stepped on
# 2                 New York, NY
# 3                   Texas, USA
# 4
# ..                         ...
# 95
# 96
# 97
# 98
# 99
#
#                                             Image URL
# 0   https://abs.twimg.com/sticky/default_profile_i...
# 1   https://pbs.twimg.com/profile_images/870712806...
# 2   https://pbs.twimg.com/profile_images/548641232...
# 3   https://pbs.twimg.com/profile_images/758470995...
# 4   https://pbs.twimg.com/profile_images/137775044...
# ..                                                ...
# 95  https://pbs.twimg.com/profile_images/140849543...
# 96  https://pbs.twimg.com/profile_images/140849543...
# 97  https://pbs.twimg.com/profile_images/140849543...
# 98  https://pbs.twimg.com/profile_images/140849543...
# 99  https://pbs.twimg.com/profile_images/140849543...
#
# [200 rows x 6 columns]
